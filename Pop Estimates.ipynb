# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
pop = pd.read_csv('/Users/avonleafisher/Desktop/cc-est2019-agesex-36.csv')

# %%
geo = pd.read_csv('/Users/avonleafisher/Desktop/NY_GEOIDS.csv')

# %%
geo = geo[['2015 GEOID', 'County']]

# %%
counties = []
for i in geo.County:
    county = i[:-10]
    counties.append(county)

# %%
geo.County = counties

# %%
geo
# Out:
#     2015 GEOID              County
# 0        36001       Albany County
# 1        36003     Allegany County
# 2        36005        Bronx County
# 3        36007       Broome County
# 4        36009  Cattaraugus County
# ..         ...                 ...
# 57       36115   Washington County
# 58       36117        Wayne County
# 59       36119  Westchester County
# 60       36121      Wyoming County
# 61       36123        Yates County
#
# [62 rows x 2 columns]

# %%
pop
# Out:
#      SUMLEV  STATE  COUNTY    STNAME        CTYNAME  YEAR  POPESTIMATE  \
# 0        50     36       1  New York  Albany County     1       304204
# 1        50     36       1  New York  Albany County     2       304208
# 2        50     36       1  New York  Albany County     3       304086
# 3        50     36       1  New York  Albany County     4       304596
# 4        50     36       1  New York  Albany County     5       305723
# ..      ...    ...     ...       ...            ...   ...          ...
# 739      50     36     123  New York   Yates County     8        25128
# 740      50     36     123  New York   Yates County     9        25059
# 741      50     36     123  New York   Yates County    10        25002
# 742      50     36     123  New York   Yates County    11        24951
# 743      50     36     123  New York   Yates County    12        24913
#
#      POPEST_MALE  POPEST_FEM  UNDER5_TOT  ...  AGE7579_FEM  AGE8084_TOT  \
# ...

# %%
df = pd.merge(pop, geo,  how='left', left_on='CTYNAME', right_on = 'County')

# %%
df = df.drop('CTYNAME', axis=1)

# %%
df
# Out:
#      SUMLEV  STATE  COUNTY    STNAME  YEAR  POPESTIMATE  POPEST_MALE  \
# 0        50     36       1  New York     1       304204       147076
# 1        50     36       1  New York     2       304208       147076
# 2        50     36       1  New York     3       304086       147026
# 3        50     36       1  New York     4       304596       147456
# 4        50     36       1  New York     5       305723       147934
# ..      ...    ...     ...       ...   ...          ...          ...
# 739      50     36     123  New York     8        25128        12194
# 740      50     36     123  New York     9        25059        12158
# 741      50     36     123  New York    10        25002        12162
# 742      50     36     123  New York    11        24951        12124
# 743      50     36     123  New York    12        24913        12132
#
#      POPEST_FEM  UNDER5_TOT  UNDER5_MALE  ...  AGE8084_MALE  AGE8084_FEM  \
# ...
