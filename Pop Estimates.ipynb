# %%
import pandas as pd

# %%
pd.read_csv('/Users/avonleafisher/Desktop/cc-est2019-agesex-36.csv')
# Out:
#      SUMLEV  STATE  COUNTY    STNAME        CTYNAME  YEAR  POPESTIMATE  \
# 0        50     36       1  New York  Albany County     1       304204
# 1        50     36       1  New York  Albany County     2       304208
# 2        50     36       1  New York  Albany County     3       304086
# 3        50     36       1  New York  Albany County     4       304596
# 4        50     36       1  New York  Albany County     5       305723
# ..      ...    ...     ...       ...            ...   ...          ...
# 739      50     36     123  New York   Yates County     8        25128
# 740      50     36     123  New York   Yates County     9        25059
# 741      50     36     123  New York   Yates County    10        25002
# 742      50     36     123  New York   Yates County    11        24951
# 743      50     36     123  New York   Yates County    12        24913
#
#      POPEST_MALE  POPEST_FEM  UNDER5_TOT  ...  AGE7579_FEM  AGE8084_TOT  \
# ...
